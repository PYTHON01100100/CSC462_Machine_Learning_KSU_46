# %% [markdown]
# Model A  THE BEST MODEL

# %%
# First of all we import all the libraries needed
#7-9-24
# I need to ReOrdering after the HW2 BECAUSE I NEED TO ORDER THE IDEAS TO REV FOR THE EXAMES AND INTERVIWES
# A Model
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
# Initialize the Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, f1_score ,confusion_matrix

# %%
# Step 1: Data Preparation and showing Data note: CSV FILE SHOULD BE IN THE SAME LOC OF THE IPYNB
data = pd.read_csv('xAPI-Edu-Data.csv') # https://www.kaggle.com/datasets/aljarah/xAPI-Edu-Data?resource=download
print('Size of weather data frame is :',data.shape)
data.head() #SHOWING THE FIRST DATASETS
# Out:
# Size of weather data frame is : (480, 17)
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father           15                16                  2
# 1        F   Father           20                20                  3
# 2        F   Father           10                 7                  0
# 3        F   Father           30                25                  5
# 4        F   Father           40                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# 0          20                   Yes                     Good
# 1          25                   Yes                     Good
# 2          30                    No                      Bad
# 3          35                    No                      Bad
# 4          50                    No                      Bad
#
#   StudentAbsenceDays Class
# 0            Under-7     M
# 1            Under-7     M
# 2            Above-7     L
# 3            Above-7     L
# 4            Above-7     M

# %%
# Encode categorical features
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html
le = LabelEncoder()
for column in data.columns:
    if data[column].dtype == type(object):
        data[column] = le.fit_transform(data[column])

# %%
# Separate features (X) and target (y)
X = data.drop('Class', axis=1)
y = data['Class']

# %%
# Split the data into training set (80%) and test set (20%) & RS =91 as the report says
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=91)

# %%
# Initialize the Random Forest Classifier
model = RandomForestClassifier()
#PARAMA
# Train the model
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
# Make predictions
y_pred = model.predict(X_test)

# %%
# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)

# %%
# Calculate the F1-score of the model
f1 = f1_score(y_test, y_pred, average='macro')

# %%
# Calculate the confusion matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
target_names = y.unique()
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=target_names )
disp.plot()

# %%
print(f"Model accuracy: {accuracy * 100:.2f}%")
print(f"F1-score: {f1:.2f}")
print("Confusion Matrix:\n", cm)
# Out:
# Model accuracy: 83.33%
# F1-score: 0.84
# Confusion Matrix:
#  [[21  0  2]
#  [ 1 28  5]
#  [ 5  3 31]]

# %% [markdown]
# Model B

# %%
# F1 Score (Macro Averaged) + Confusion Matrix (Optional)
# First of all we import all the libraries needed
# 9-9-24
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score ,confusion_matrix

# %%
# Load the dataset from the file (Note: Should be in the same loc with the Source code)
data = pd.read_csv('xAPI-Edu-Data.csv')
print('Size of the student frame is: ',data.shape)
#show the DataSet
data.head()
# Out:
# Size of the student frame is:  (480, 17)
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father           15                16                  2
# 1        F   Father           20                20                  3
# 2        F   Father           10                 7                  0
# 3        F   Father           30                25                  5
# 4        F   Father           40                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# 0          20                   Yes                     Good
# 1          25                   Yes                     Good
# 2          30                    No                      Bad
# 3          35                    No                      Bad
# 4          50                    No                      Bad
#
#   StudentAbsenceDays Class
# 0            Under-7     M
# 1            Under-7     M
# 2            Above-7     L
# 3            Above-7     L
# 4            Above-7     M

# %%
# Encode features
e = LabelEncoder()
for column in data.columns:
    if data[column].dtype == object:
        data[column] = e.fit_transform(data[column])

# %%
# Separate features and target
X = data.drop('Class', axis=1)
y = data['Class']
target_names = y.unique()

# %%
# Split the data into training set (80%) and test set (20%) & RS =91 as the report says
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=91)

# %%
# Initialize the Random Forest Classifier with hyperparameters
model = RandomForestClassifier(max_depth=10 , criterion='gini' )

"""
model = RandomForestClassifier(
    n_estimators=100,        # Number of trees in the forest
    max_depth=10,            # Maximum depth of each tree
    min_samples_split=5,     # Minimum number of samples required to split a node
    min_samples_leaf=2,      # Minimum number of samples required in a leaf node
    criterion='gini',        # Function to measure the quality of a split ('gini' or 'entropy')
    max_features='sqrt',     # Number of features to consider for the best split ('auto', 'sqrt', or 'log2')
    random_state=42,         # Random seed for reproducibility
    n_jobs=-1                # Number of jobs to run in parallel (-1 means using all processors)
)
"""
# Out:
# "\nmodel = RandomForestClassifier(\n    n_estimators=100,        # Number of trees in the forest\n    max_depth=10,            # Maximum depth of each tree\n    min_samples_split=5,     # Minimum number of samples required to split a node\n    min_samples_leaf=2,      # Minimum number of samples required in a leaf node\n    criterion='gini',        # Function to measure the quality of a split ('gini' or 'entropy')\n    max_features='sqrt',     # Number of features to consider for the best split ('auto', 'sqrt', or 'log2')\n    random_state=42,         # Random seed for reproducibility\n    n_jobs=-1                # Number of jobs to run in parallel (-1 means using all processors)\n)\n"

# %%
# Train the model
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=10)

# %%
# Make predictions
y_pred = model.predict(X_test)

# %%
# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)

# %%
# Calculate the F1-score of the model
f1 = f1_score(y_test, y_pred, average='macro')

# %%
# Calculate the confusion matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=target_names )
disp.plot()

# %%
print(f"Model accuracy: {accuracy * 100:.2f}%")
print(f"F1-score: {f1:.2f}")
print("Confusion Matrix:\n", cm)
# Out:
# Model accuracy: 81.25%
# F1-score: 0.82
# Confusion Matrix:
#  [[21  0  2]
#  [ 0 27  7]
#  [ 5  4 30]]

# %% [markdown]
# Model C

# %%
#
# F1 Score (Macro Averaged) + Confusion Matrix (Optional)
# First of all we import all the libraries needed
# 9-9-24
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
# Initialize the Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, f1_score ,confusion_matrix

# %%
# Load the dataset from the file (Note: Should be in the same loc with the Source code)
data = pd.read_csv('xAPI-Edu-Data.csv')
print('Size of the student frame is: ',data.shape)
#show the DataSet
data.head()
# Out:
# Size of the student frame is:  (480, 17)
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father           15                16                  2
# 1        F   Father           20                20                  3
# 2        F   Father           10                 7                  0
# 3        F   Father           30                25                  5
# 4        F   Father           40                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# 0          20                   Yes                     Good
# 1          25                   Yes                     Good
# 2          30                    No                      Bad
# 3          35                    No                      Bad
# 4          50                    No                      Bad
#
#   StudentAbsenceDays Class
# 0            Under-7     M
# 1            Under-7     M
# 2            Above-7     L
# 3            Above-7     L
# 4            Above-7     M

# %%
# Encode features
e = LabelEncoder()
for column in data.columns:
    if data[column].dtype == object:
        data[column] = e.fit_transform(data[column])

# %%
# Separate features and target
X = data.drop('Class', axis=1)
y = data['Class']
target_names = y.unique()

# %%
# Split the data into training set (80%) and test set (20%) & RS =91 as the report says
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=91)

# %%
# Initialize the Decision Tree Classifier with hyperparameters
model = DecisionTreeClassifier(max_depth=5, criterion='gini')
#model = DecisionTreeClassifier()

# %%
# Train the model
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
# Make predictions
y_pred = model.predict(X_test)

# %%
# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)

# %%
# Calculate the F1-score of the model
f1 = f1_score(y_test, y_pred, average='macro')

# %%
# Calculate the confusion matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=target_names )
disp.plot()

# %%
print(f"Model accuracy: {accuracy * 100:.2f}%")
print(f"F1-score: {f1:.2f}")
print("Confusion Matrix:\n", cm)
# Out:
# Model accuracy: 77.08%
# F1-score: 0.78
# Confusion Matrix:
#  [[19  0  4]
#  [ 0 26  8]
#  [ 6  4 29]]

# %% [markdown]
# Model D

# %%
# First of all we import all the libraries needed
#7-9-24
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
# Initialize the Random Forest Classifier
from sklearn.neighbors import KNeighborsClassifier

# %%
# Step 1: Data Preparation and showing Data note: CSV FILE SHOULD BE IN THE SAME LOC OF THE IPYNB
data = pd.read_csv('xAPI-Edu-Data.csv') # https://www.kaggle.com/datasets/aljarah/xAPI-Edu-Data?resource=download
print('Size of weather data frame is :',data.shape)
data.head() #SHOWING THE FIRST DATASETS
# Out:
# Size of weather data frame is : (480, 17)
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father           15                16                  2
# 1        F   Father           20                20                  3
# 2        F   Father           10                 7                  0
# 3        F   Father           30                25                  5
# 4        F   Father           40                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# 0          20                   Yes                     Good
# 1          25                   Yes                     Good
# 2          30                    No                      Bad
# 3          35                    No                      Bad
# 4          50                    No                      Bad
#
#   StudentAbsenceDays Class
# 0            Under-7     M
# 1            Under-7     M
# 2            Above-7     L
# 3            Above-7     L
# 4            Above-7     M

# %%
# Encode categorical features
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html
le = LabelEncoder()
for column in data.columns:
    if data[column].dtype == type(object):
        data[column] = le.fit_transform(data[column])

# %%
# Separate features (X) and target (y)
X = data.drop('Class', axis=1)
y = data['Class']
target_names = y.unique()

# %%
# Split the data into training set (80%) and test set (20%) & RS =91 as the report says
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=91)

# %%
# Initialize the KNN Classifier with hyperparameters
model = KNeighborsClassifier(n_neighbors=5, weights='uniform', metric='minkowski')

# %%
# Train the model
model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
# Make predictions
y_pred = model.predict(X_test)

# %%
# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)

# %%
# Calculate the F1-score of the model
f1 = f1_score(y_test, y_pred, average='macro')

# %%
# Calculate the confusion matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=target_names )
disp.plot()

# %%
print(f"Model accuracy: {accuracy * 100:.2f}%")
print(f"F1-score: {f1:.2f}")
print("Confusion Matrix:\n", cm)
# Out:
# Model accuracy: 56.25%
# F1-score: 0.57
# Confusion Matrix:
#  [[14  0  9]
#  [ 2 21 11]
#  [13  7 19]]

# %% [markdown]
# Model E

# %%
# First of all we import all the libraries needed
#7-9-24
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
# Initialize the Random Forest Classifier
from sklearn.neighbors import KNeighborsClassifier

# %%
# Step 1: Data Preparation and showing Data note: CSV FILE SHOULD BE IN THE SAME LOC OF THE IPYNB
data = pd.read_csv('xAPI-Edu-Data.csv') # https://www.kaggle.com/datasets/aljarah/xAPI-Edu-Data?resource=download
print('Size of weather data frame is :',data.shape)
data.head() #SHOWING THE FIRST DATASETS
# Out:
# Size of weather data frame is : (480, 17)
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father           15                16                  2
# 1        F   Father           20                20                  3
# 2        F   Father           10                 7                  0
# 3        F   Father           30                25                  5
# 4        F   Father           40                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# 0          20                   Yes                     Good
# 1          25                   Yes                     Good
# 2          30                    No                      Bad
# 3          35                    No                      Bad
# 4          50                    No                      Bad
#
#   StudentAbsenceDays Class
# 0            Under-7     M
# 1            Under-7     M
# 2            Above-7     L
# 3            Above-7     L
# 4            Above-7     M

# %%
# Encode categorical features
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html
le = LabelEncoder()
for column in data.columns:
    if data[column].dtype == type(object):
        data[column] = le.fit_transform(data[column])

# %%
# Separate features (X) and target (y)
X = data.drop('Class', axis=1)
y = data['Class']
target_names = y.unique()

# %%
# Split the data into training set (80%) and test set (20%) & RS =91 as the report says
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=91)

# %%
# Initialize the SVC Classifier
from sklearn.svm import SVC
model = SVC()

# %%
# Train the model
model.fit(X_train,y_train)
# Out:
# SVC()

# %%
# Make predictions
y_pred = model.predict(X_test)

# %%
# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)

# %%
# Calculate the F1-score of the model
f1 = f1_score(y_test, y_pred, average='macro')

# %%
# Calculate the confusion matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=target_names )
disp.plot()

# %%
print(f"Model accuracy: {accuracy * 100:.2f}%")
print(f"F1-score: {f1:.2f}")
print("Confusion Matrix:\n", cm)
# Out:
# Model accuracy: 62.50%
# F1-score: 0.63
# Confusion Matrix:
#  [[13  0 10]
#  [ 0 22 12]
#  [ 7  7 25]]

# %%
# First of all we import all the libraries needed
#7-9-24
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
# Initialize the Random Forest Classifier
from sklearn.neighbors import KNeighborsClassifier

# %%
# Step 1: Data Preparation and showing Data note: CSV FILE SHOULD BE IN THE SAME LOC OF THE IPYNB
data = pd.read_csv('xAPI-Edu-Data.csv') # https://www.kaggle.com/datasets/aljarah/xAPI-Edu-Data?resource=download
print('Size of weather data frame is :',data.shape)
data.head() #SHOWING THE FIRST DATASETS
# Out:
# Size of weather data frame is : (480, 17)
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father           15                16                  2
# 1        F   Father           20                20                  3
# 2        F   Father           10                 7                  0
# 3        F   Father           30                25                  5
# 4        F   Father           40                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# 0          20                   Yes                     Good
# 1          25                   Yes                     Good
# 2          30                    No                      Bad
# 3          35                    No                      Bad
# 4          50                    No                      Bad
#
#   StudentAbsenceDays Class
# 0            Under-7     M
# 1            Under-7     M
# 2            Above-7     L
# 3            Above-7     L
# 4            Above-7     M

# %%
# Encode categorical features
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html
le = LabelEncoder()
for column in data.columns:
    if data[column].dtype == type(object):
        data[column] = le.fit_transform(data[column])

# %%
# Separate features (X) and target (y)
X = data.drop('Class', axis=1)
y = data['Class']
target_names = y.unique()

# %%
# Split the data into training set (80%) and test set (20%) & RS =91 as the report says
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=91)

# %%
# Initialize the KNN Classifier with hyperparameters
#from sklearn.svm import SVC
#model = SVC()
#from xgboost import XGBClassifier
#model = XGBClassifier(n_estimators=100, learning_rate=0.1)  # Adjust hyperparameters as needed
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
# Train the model
model.fit(X_train,y_train)
# Out:
# C:\Users\CSC264\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Make predictions
y_pred = model.predict(X_test)

# %%
# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)

# %%
# Calculate the F1-score of the model
f1 = f1_score(y_test, y_pred, average='macro')

# %%
# Calculate the confusion matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=target_names )
disp.plot()

# %%
print(f"Model accuracy: {accuracy * 100:.2f}%")
print(f"F1-score: {f1:.2f}")
print("Confusion Matrix:\n", cm)
# Out:
# Model accuracy: 76.04%
# F1-score: 0.77
# Confusion Matrix:
#  [[20  0  3]
#  [ 0 25  9]
#  [ 7  4 28]]
